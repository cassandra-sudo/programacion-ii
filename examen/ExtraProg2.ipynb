# %% [markdown]
# <div class="alert alert-block alert-info">
# <center>
# <img src="https://www.wikicity.com/w/images/8/87/Facultad_de_Ciencias.png?raw=1" width="550">
# </center>
#
# **Instrucciones.**
#
# 1. Antes de comenzar reinicia el kernel. En la barra de menu selecciona:
#     - `Kernel` $\rightarrow$ `Restart Kernel and Clear Outputs of All Cells...`
# 2. Ejecuta todas las celdas de código como se indica en la notebook.
#     - Para ejecutar una celda haz clic en ella y luego presiona las teclas `<Shift> + <Enter>`.
# 3. Asegurate contestar todas las preguntas y escribir las respuestas donde encuentres el texto: `YOUR ANSWER HERE`.
# 4. Asegurate de realizar todos los ejercicios y escribir los códigos donde encuentres el texto: `YOUR CODE HERE`.
#     - No olvides comentar o eliminar las líneas de código que dicen:
#         + `raise NotImplementedError()`
#     - Asegurate de **documentar tu código**.
# 5. NO DUPLIQUES CELDAS. Si necesitas realizar algunas pruebas, abre una nueva celda y copia ahí el código que deseas probar.
#     - Algunas celdas solo con de tipo READ ONLY por lo que no podrás modificarlas. Si deseas probar código de esas celdas, puedes abrir una nueva celda y copiar el código en esta útlima para hacer tus pruebas.
#
# 6. Para evaluar tus respuestas, ejecuta las celdas que contienen código como el siguiente:
#     - `quiz.eval_numeric(...)`
#     - Estas celdas te dirán si el trabajo está correctamente realizado y en caso de error te avisará y te dará algunas pistas.
# 7. Si las cosas se complican y obtienes muchos errores que no se pueden solucionar, regresa al paso 1 y vuelve a comenzar. ¡No te preocupes!, tu trabajo estará a salvo, solo se reiniciará el kernel para eliminar de la memoria la basura acumulada.
# 8. Al responder estas preguntas debes seguir el estandar de codificación que se encuentra *RECURSOS/Formatos/programas_formato.pdf* en MACTI. En caso de error, revisa el mensaje, la ayuda, busca una solución en las referencias y **recuerda hacer uso del debugger**. Finalmente, utiliza el botón *Validate*, para asegurarte que tu *notebook* pasa todas las pruebas y por último envía tu notebook con el botón *Submmit*
# </div>

# %% [markdown]
# Nombre:

# %% [markdown]
# ---

# %% [markdown]
# <center>
#     <img src="https://www.fciencias.unam.mx/sites/default/files/logoFC85.png" alt="Facultad de Ciencias" width="500" height="500">
# </center>
# <font color="Teal">
#   <h2 align="center"><i>Examen Extraordinario: Programación 2</i></h2>
# </font>
# <font color="Black">
#   <h5 align="center"><i>Profesor: M. en C. Miguel Angel Pérez León</i></h5>
#   <h5 align="center"><i>Profesor: M. en C. Aramis Arias Romero</i></h5>
# </font>

# %% [markdown]
# <div class="alert alert-info">
#
# ## **(10 Puntos) Examen**
#
# <font color="Black">**Descripción:** La finalidad de este examen es que respondas cada una de los incisos siguiendo las instrucciones.
# </font>
#
# <font color="Black">**Celdas:** Existen celdas que son solo de lectura y algunas otras que sean editables tanto de tipo texto (para respuestas teóricas) como de código (para respuestas prácticas).
# </font>
#
# <font color="Black">**Validación:** Toda celda en que se pida escribir código tiene su validación, úsala para saber si tu respuesta es correcta o es necesario corregir.
# </font>
#
# <font color="Black">**Estructura del examen:** La clase `Nodo` y `AB` (Arbol Binario) ya han sido definidas. Y con base en estas clase, es necesario implementar las clases `ABB` (Arbol Binario de Búsqueda) y `AAVL` (Arbol Balanceado). Haciendo uso de los conceptos de herencia y programación orientada a objetos (POO), es necesario definir la clase `ABB` y sus respectivas operaciones, de igual manera es necesario definir la clase `AAVL` heredando de la clase `ABB`.
# </font>
#
# <font color="Black">**Si tu código no aprueba la validación, las preguntas asociadas a esa sección se invalidan.**
# </font>
#
# <font color="Black">En cada pregunta debes ser tan explícito como la calificación que desees obtener. **En caso que tu justificación o desarrollo esté incompleto, también lo será la calificación asignada**.
# </font>
#
# <font color="Black">**ESTRICTAMENTE PROHIBIDO HACER USO DE FUNCIONES QUE NO HAYAS DEFINIDO.**
# </font>
#
# <font color="Black">Una vez que ya hayas terminado el examen, **debes entregarlo mediante la plataforma usando el botón de *Submit*.**
# </font>
#
# <font color="Black">**Cualquier violación a los estándares de entrega será penalizada.**
# </font>

# %% [markdown]
# <div class="alert alert-danger">
#
# **Hey:** debes ejecutar la siguiente celda para que todo funcione.
#
# </div>

# %%
from macti.eval import Quiz
quiz = Quiz('1', 'ManejoDatos')

# %% [markdown]
# <div class="alert alert-info">
#
# ## La clase `Nodo`
#
# La clase `Nodo` se muestra en la siguiente celda y cumple con la finalidad de definir la estructura básica para crear estructuras más elaboradas con son los Arboles Binarios de Búsqueda o los Arboles Balanceados.
#
# **NO MODIFIQUES LA CLASE `Nodo`, DE LO CONTRARIO TU CALIFICACIÓN SERÁ DE CERO**
#
# Podemos pensar que un nodo se ve de la siguiente forma.
#
# <center>
# <img src="https://github.com/jugernaut/Numerico2021/blob/master/Figuras/raicesNumericas/nodo.png?raw=1" width="700">
# </center>
#
# Tomando como base la clase `Nodo` y usala para responder lo que se pide en el examen.

# %%
# Clase Nodo necesaria para generar arboles binarios
class Nodo(object):
  '''
  Constructor de nodos
  dato: es el contenido del nodo
  '''
  def __init__(self, dato):
    self.izq = None
    self.dato = dato
    self.der = None
    self.padre = None

  # Nos dice si el nodo tiene al menos un hijo    
  def tieneHijos(self):
    return self.izq is not None and self.der is not None
  
  # Nos dide si el nodo es un hijo izquierdo
  def esIzq(self):
    return self.padre.izq == self
  
  # Nos dice si el nodo es un hijo derecho
  def esDer(self):
    return self.padre.der == self
  
  # Imprime el contenido del nodo
  def __str__(self):
    if self.dato is None:
      pass
    else:
      return '{}'.format(self.dato)

# %% [markdown]
# <div class="alert alert-info">
#
# ## La clase `AB` Arboles Binarios
#
# A continuación se define la clase `AB` la cual es una implementación de la estructura de datos conocida como Arbol Binario.
#
# Esta clase ya cuenta con algunos atributos (raíz) y algunos métodos que se van a utilizar en las siguientes clases.
#
# Te recomiendo leer la documentación para entender cómo funciona la clase `AB`.
#
# **NO MODIFIQUES LA CLASE `AB`, DE LO CONTRARIO TU CALIFICACIÓN SERÁ DE CERO**

# %%
import random

''' Clase AB (ArbolBinario), genera la estructura de un arbol binario, asi como sus funciones.'''
class AB(object):

  ''' Consructor de arboles binarios'''
  def __init__(self, dato):
    self.raiz = Nodo(dato)
      
  ''' Elimina todo el arbol'''
  def elimina(self):
    self.raiz = None
      
  ''' Devuelve el nivel del nodo que se le pasa como parametro.
      La raiz se ubica en el nivel cero'''
  def nivel(self, nodo):
    if nodo is None:
      return -1
    else:
      return 1 + self.nivel(nodo.padre)

  ''' Devuelve la altura a partir del nodo que se le pasa como parametro,
      si el arbol es vacio la altura es cero, si no se le suma 1 al maximo
      de las alturas de sus hijos'''
  def altura(self, nodo):
    if nodo is None:
      return 0
    else:
      return 1 + max(self.altura(nodo.izq), self.altura(nodo.der))
      
  ''' Inserta recursivamente un dato en el arbol de manera recursiva
      nodo: es el nodo a partir del cual se quiere insertar
      dato: es el dato que se quiere insertar
  '''
  def insertar_nodo(self, nodo, dato):
    # si el nodo es vacio ahi se crea el nuevo nodo
    if nodo is None:
      nuevo_nodo = Nodo(dato)
      return nuevo_nodo
    # dado que en los AB no hay un orden el nuevo nodo se inserta donde sea
    if bool(random.getrandbits(1)):
      nuevo_nodo = self.insertar_nodo(nodo.izq, dato)
      nodo.izq = nuevo_nodo
      nuevo_nodo.padre = nodo
    else:
      nuevo_nodo = self.insertar_nodo(nodo.der, dato)
      nodo.der = nuevo_nodo
      nuevo_nodo.padre = nodo
    #nodo guarda toda la ruta de donde sera insertado el dato
    #hasta caer en el caso base, es por eso que se devuelve    
    return nodo
  
  ''' Inserta un nodo en el arbol, a partir de la raiz'''
  def insertar(self, dato):
    #Se inserta el dato desde la raiz
    self.insertar_nodo(self.raiz, dato)
      
  ''' Recorre el arbol enorden e imprime cada uno de sus nodos'''
  def recorrido_enorden(self, nodo, recorrido):
    if nodo is not None:
      self.recorrido_enorden(nodo.izq, recorrido)
      recorrido.append(nodo.dato)
      self.recorrido_enorden(nodo.der, recorrido)

  ''' Recorre el arbol preorden e imprime cada uno de sus nodos'''
  def recorrido_preorden(self, nodo, recorrido):
    if nodo is not None:
      recorrido.append(nodo.dato)
      self.recorrido_preorden(nodo.izq, recorrido)
      self.recorrido_preorden(nodo.der, recorrido)

  ''' Recorre el arbol postorden e imprime cada uno de sus nodos'''
  def recorrido_postorden(self, nodo, recorrido):
    if nodo is not None:
      self.recorrido_postorden(nodo.izq, recorrido)
      self.recorrido_postorden(nodo.der, recorrido)
      recorrido.append(nodo.dato)

# %% [markdown]
# <div class="alert alert-info">
#
# ## (5 puntos) La clase `ABB` Arboles Binarios de Búsqueda
#
# Haciendo uso de herencia, y tomando como base la clase `AB` define la clase `ABB` la cual es una implementación de la estructura de datos conocida como Arbol Binario de Búsqueda.
#
# Puedes notar que solo se tiene la *firma* de los métodos, es necesario que completes el código (apoyándote de la documentación) para que la clase `ABB` cumpla con todos los requerimientos y pase las pruebas. Los métodos a implemetar son:
#
# * `busqueda`: recibe un nodo a partir del cual buscar y un dato a buscar y devuelve el nodo en el cual se encuentra el dato o `None` en caso de que no exista el dato.
# * `insertar`: Recibe un dato y este se intenta insertar desde la raíz, **no se permiten datos duplicados**.
# * `borrar`: Recibe un dato, mismo que se intenta borrar en caso de que exista.
#
# Puedes apoyarte en la clase `AB` si es que así lo consideras necesario.
#
# **NO MODIFIQUES LA CLASE `AB`, DE LO CONTRARIO TU CALIFICACIÓN SERÁ DE CERO.**

# %%
''' Clase arbol binario de busqueda, genera la estructura de un arbol binario
    de busqueda asi como sus funciones.'''
class ABB(AB):
    
  def busqueda(self, nodo, dato):
    return None
  def insertar(self, dato):
    return None
  def borrar(self, dato):
    return None

# %% [markdown]
# <div class="alert alert-info">
#
# ## Responde las siguientes preguntas.

# %% [markdown]
# <div class="alert alert-info">
#
# ## `busqueda`
#
# ¿Cuál es el peor caso cuando se busca un dato en un árbol binario de búsqueda y a qué orden de complejidad respecto al tiempo pertenece el método `busqueda`. ¡Justifica tu respuesta!

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <div class="alert alert-info">
#
# ## `insertar`
#
# ¿A qué orden de complejidad respecto al tiempo y a la memoria pertenece el método `insertar`. ¡Justifica tu respuesta!

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <div class="alert alert-info">
#
# ## `borrar`
#
# ¿A qué orden de complejidad respecto al tiempo y a la memoria pertenece el método `borrar`. ¡Justifica tu respuesta!

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <div class="alert alert-info">
#
# ## `elimina`
#
# ¿A qué orden de complejidad respecto al tiempo y a la memoria pertenece el método `elimina`. ¡Justifica tu respuesta!

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <div class="alert alert-info">
#
# ## Pruebas y Validación
#
# En la siguiente celda de código se prueban los métodos definidos previamente (`insertar` y `borrar`). Una vez que realizan estas operaciones sobre el objeto `abb`, dicho árbol debería quedar así.
#
# <center>
# <img src="https://github.com/jugernaut/Numerico2021/blob/master/Figuras/raicesNumericas/abbex.png?raw=1" width="700">
# </center>
#
# De tal manera que, si tú código fue definido de manera correcta, debería pasar la prueba de validación.

# %%
abb = ABB(15)
abb.insertar(10)
abb.insertar(20)
abb.insertar(8)
abb.insertar(14)
abb.insertar(0)
abb.insertar(35)
abb.insertar(99)
abb.insertar(30)
abb.borrar(99)
abb.borrar(15)
abb.insertar(90)

# %%
preordenABB = []
print('recorido en preorden')
abb.recorrido_preorden(abb.raiz, preordenABB)
print(preordenABB)
quiz.eval_datastruct('1',  preordenABB)

# %% [markdown]
# <div class="alert alert-info">
#
# ## La clase `ArbolAVL` Arboles Balanceados
#
# Heredando de la clase `ABB` es necesario definir la clase `ArbolAVL` misma que es una implementación de la estructura de datos conocida como Arboles Balanceados.
#
# Dado que la forma en la que se insertan y eliminan datos en un Arbol Balanceado es diferente a como se lleva a cabo en los Arboles Binarios de Búsqueda, es necesario redefinir algunos métodos. Los métodos a implemetar son:
#
# * `insertar`: Una vez que se inserta un dato, es necesario rebalancear el árbol.
# * `borrar`: Una vez que se borra un dato, es necesario rebalancear el árbol.

# %%
class ArbolAVL(ABB):
    
  def insertar(self, dato):
    return None

  def borrar(self, dato):
    return None

# %% [markdown]
# <div class="alert alert-info">
#
# ## Responde las siguientes preguntas.

# %% [markdown]
# <div class="alert alert-info">
#
# ## `busqueda`
#
# ¿Cuál es el peor caso cuando se búsca un dato en un árbol binario de búsqueda y a qué orden de complejidad respecto al tiempo pertenece el método `busqueda`. ¡Justifica tu respuesta!

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <div class="alert alert-info">
#
# ## `insertar`
#
# ¿A qué orden de complejidad respecto al tiempo y a la memoria pertenece el método `insertar`. ¡Justifica tu respuesta!

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <div class="alert alert-info">
#
# ## `borrar`
#
# ¿A qué orden de complejidad respecto al tiempo y a la memoria pertenece el método `borrar`. ¡Justifica tu respuesta!

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <div class="alert alert-info">
#
# ## `elimina`
#
# ¿A qué orden de complejidad respecto al tiempo y a la memoria pertenece el método `elimina`. ¡Justifica tu respuesta!

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# <div class="alert alert-info">
#
# ## Pruebas y Validación
#
# En la siguiente celda de código se prueban los métodos definidos previamente (`insertar` y `borrar`). Una vez que realizan estas operaciones sobre el objeto `aavl`, dicho árbol debería quedar así.
#
# <center>
# <img src="https://github.com/jugernaut/Numerico2021/blob/master/Figuras/raicesNumericas/aavlex.png?raw=1" width="700">
# </center>
#
# De tal manera que, si tú código fue definido de manera correcta, debería pasar la prueba de validación.

# %%
aavl = ArbolAVL(15)
aavl.insertar(10)
aavl.insertar(5)
aavl.insertar(16)
aavl.insertar(17)
aavl.insertar(9)
aavl.insertar(20)
aavl.borrar(99)
aavl.borrar(15)
aavl.insertar(90)

# %%
preordenAAVL = []
print('recorido en preorden')
aavl.recorrido_preorden(aavl.raiz, preordenAAVL)
print(preordenAAVL)
quiz.eval_datastruct('2',  preordenAAVL)
